# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamerchan6/PROGCOM-B/blob/main/Clase_16_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Diccionarios
#
# ```
# tiene formato de código
# ```
# Un diccionario es una colección de elementos donde cada uno key o llaves y asociada tiene un value o valor.
# Propiedades:
# *Dinámicos:pueden crecer y añadir elementos.
# *Son indexados:desde las llaves.
# *Pueden ser aninado:
#
# Sintaxis
# ```
# diccionario={}
# diccionario={llave:valor,
# llaves2:valor2,....,
# llaven:valorn}
# ```

# %%
pedido={1:["hamburguesa", "pizza", "perro", "gaseosa","pola","agua"],
        2:["sushi","spaguetti","gaseosa","jugo"],
        3:["ensalada","agua"]}

# %%
constructores={"nombres":["Ana", "Valerie","Roxane", "JUlián","Mayra"],
               "notas":[0,1,5,2,4.9,4.9]}

# %%
print(pedido)
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'], 2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'], 3: ['ensalada', 'agua']}

# %%
{1:["hamburguesa", "pizza", "perro", "gaseosa","pola","agua"],
        2:["sushi","spaguetti","gaseosa","jugo"],
        3:["ensalada","agua"]}
# Out:
# {1: ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua'],
#  2: ['sushi', 'spaguetti', 'gaseosa', 'jugo'],
#  3: ['ensalada', 'agua']}

# %%
#yo quiero saber, qué pidio la mesa 1
pedido[1]
# Out:
# ['hamburguesa', 'pizza', 'perro', 'gaseosa', 'pola', 'agua']

# %%
if "perro" in pedido[1]:
  print("Si pidieron perro")
else:
    print("No pidieron")
# Out:
# Si pidieron perro

# %%
pedido.get

# %%
print(constructores.get("notas"))
# Out:
# [0, 1, 5, 2, 4.9, 4.9]

# %%
 constructores=["notas"]

# %%
for c in constructores["notas"]:
  if c <3:print("Reprobo")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1814/494330404.py in <cell line: 0>()
# ----> 1 for c in constructores["notas"]:
#       2   if c <3:print("Reprobo")
#
# TypeError: list indices must be integers or slices, not str

# %%
p=[n for n in constructores["notas"] if n <3 print("Perdió")]
p
# Out:
#   File "/tmp/ipykernel_1814/1129591354.py", line 1
#     p=[n for n in constructores["notas"] if n <3 print("Perdió")]
#                                                  ^
# SyntaxError: invalid syntax
