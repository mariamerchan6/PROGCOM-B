# %% [markdown]
# <a href="https://colab.research.google.com/github/mariamerchan6/PROGCOM-B/blob/main/Clase_(08_09).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pregunta d einvestigación
#
# ```
# son aspectos revelantes de la investigacion que desea abordar
# ```
# *Que deso saber?
# *Existe algun punto interesante y concreto que provenga de los datos?
# *los datos obtenidos proveen respuestas a lo que necesito saber?
# *como podre examinar los datos?
# *puedo responder la pregunta?
#
#
# Debe ser:revelante,manejable,específico,simple y sencilla,interesante,es legítima,que se pueda responder,no puede ser dipootonica(ni sí ni no),etica.

# %% [markdown]
# Elementos a conciderar:
# -El constructor:que idea estoy investigando?
# -Ir mas alla del dato
# -Aplicacion:es lo suficientemente amplia como para mstrar relevancia?
